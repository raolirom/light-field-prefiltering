# %%
import numpy as np
from matplotlib import pyplot

fig, ax = pyplot.subplots(constrained_layout=True, figsize=(6, 6))

x = np.arange(100000) + 1
w = np.linspace(0.1, 100.0, 1000)

s = np.sum(np.sinc(x[np.newaxis, :] / w[:, np.newaxis]), axis=-1) * 2 + 1

l = ax.plot(w, s)
